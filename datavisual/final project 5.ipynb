# %%
import os
os.getlogin()
# Out:
# 'erfanhossseinabadi'

# %%
import socket 
socket.gethostbyname(socket.gethostname())
# Out:
# '127.0.1.1'

# %%
# !whoami
# Out:
# erfanhossseinabadi

# %%
from datetime import datetime

current_time =datetime.now()
print(current_time)
print("Ерфан Хосейнабади И.Т.")
# Out:
# 2024-12-23 18:40:01.554833
# Ерфан Хосейнабади И.Т.

# %%
import numpy as np
import pandas as pd
import scipy.stats as sps
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import warnings

# %matplotlib inline 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('5_ticket_price.csv')
df.head()
# Out:
#       Тариф    Цена
# 0  Business  203300
# 1  Business  201300
# 2  Business  199800
# 3  Business  199300
# 4  Business  193100

# %%
df.tail()
# Out:
#        Тариф  Цена
# 356  Economy  3400
# 357  Economy  3300
# 358  Economy  3200
# 359  Economy  3100
# 360  Economy  3000

# %%
print(df.to_string())
# Out:
#         Тариф    Цена
# 0    Business  203300
# 1    Business  201300
# 2    Business  199800
# 3    Business  199300
# 4    Business  193100
# 5    Business  186200
# 6    Business  185300
# 7    Business  184500
# 8    Business  150400
# 9    Business  146400
# 10   Business  145300
# 11   Business  144300
# 12   Business  133200
# 13   Business  132900
# 14   Business  124600
# 15   Business  117400
# 16   Business  115000
# 17   Business  111600
# 18   Business  106800
# 19   Business  105900
# 20   Business  105400
# 21   Business  101000
# 22   Business   99800
# 23   Business   94000
# 24   Business   92200
# 25   Business   91700
# 26   Business   90500
# 27   Business   89800
# 28   Business   89600
# 29   Business   89100
# 30   Business   88300
# 31   Business   87700
# 32   Business   87300
# 33   Business   86900
# 34   Business   86800
# 35   Business   86000
# 36   Business   85200
# 37   Business   84000
# 38   Business   83800
# 39   Business   83700
# ...

# %%
pd.DataFrame(df)
# Out:
#         Тариф    Цена
# 0    Business  203300
# 1    Business  201300
# 2    Business  199800
# 3    Business  199300
# 4    Business  193100
# ..        ...     ...
# 356   Economy    3400
# 357   Economy    3300
# 358   Economy    3200
# 359   Economy    3100
# 360   Economy    3000
#
# [361 rows x 2 columns]

# %%
plt.figure(figsize=(14, 8))
sns.histplot(data=df, x='Цена', hue='Тариф', kde=True)
plt.title('Ticket Prices by Rate', fontsize=20)
plt.xlabel('Ticket Prices', fontsize=16)
plt.ylabel('Density', fontsize=16)
plt.legend(['business','econoomy'])
plt.show()
